# %% [markdown]
# #

# %%
import warnings

# %%
warnings.simplefilter('ignore')

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv("C:\\Users\\aedpu\\Downloads\\Admission_Predict.csv")

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#     Research  Chance of Admit
# 0        Yes              0.92
# 1        Yes              0.76
# 2        Yes              0.72
# 3        Yes              0.80
# 4         No              0.65
# ..       ...               ...
# 395      Yes              0.82
# 396      Yes              0.84
# 397      Yes              0.91
# 398       No              0.67
# 399      Yes              0.95
#
# [400 rows x 9 columns]

# %%
GA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    object
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.2+ KB

# %%
newdataset=GA.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research'],axis=1)

# %%
newdataset
# Out:
#      GRE Score  Chance of Admit
# 0          337              0.92
# 1          324              0.76
# 2          316              0.72
# 3          322              0.80
# 4          314              0.65
# ..         ...               ...
# 395        324              0.82
# 396        325              0.84
# 397        330              0.91
# 398        312              0.67
# 399        333              0.95
#
# [400 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)

# %%
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[337],
#        [324],
#        [316],
#        [322],
#        [314],
#        [330],
#        [321],
#        [308],
#        [302],
#        [323],
#        [325],
#        [327],
#        [328],
#        [307],
#        [311],
#        [314],
#        [317],
#        [319],
#        [318],
#        [303],
#        [312],
#        [325],
#        [328],
#        [334],
#        [336],
#        [340],
#        [322],
#        [298],
#        [295],
#        [310],
#        [300],
#        [327],
#        [338],
#        [340],
#        [331],
#        [320],
#        [299],
#        [300],
#        [304],
#        [307],
#        [308],
#        [316],
#        [313],
#        [332],
#        [326],
#        [322],
#        [329],
#        [339],
#        [321],
#        [327],
#        [313],
#        [312],
#        [334],
#        [324],
#        [322],
#        [320],
#        [316],
#        [298],
#        [300],
#        [311],
#        [309],
#        [307],
#        [304],
#        [315],
#        [325],
#        [325],
#        [327],
#        [316],
#        [318],
#        [328],
#        [332],
#        [336],
#        [321],
#        [314],
#        [314],
#        [329],
#        [327],
#        [301],
#        [296],
#        [294],
#        [312],
#        [340],
#        [320],
#        [322],
#        [340],
#        [319],
#        [315],
#        [317],
#        [314],
#        [316],
#        [318],
#        [299],
#        [298],
#        [301],
#        [303],
#        [304],
#        [306],
#        [331],
#        [332],
#        [323],
#        [322],
#        [312],
#        [314],
#        [317],
#        [326],
#        [316],
#        [329],
#        [338],
#        [331],
#        [304],
#        [305],
#        [321],
#        [301],
#        [320],
#        [311],
#        [310],
#        [299],
#        [290],
#        [296],
#        [327],
#        [335],
#        [334],
#        [310],
#        [308],
#        [301],
#        [300],
#        [323],
#        [319],
#        [326],
#        [333],
#        [339],
#        [303],
#        [309],
#        [323],
#        [333],
#        [314],
#        [312],
#        [316],
#        [326],
#        [318],
#        [329],
#        [332],
#        [331],
#        [340],
#        [325],
#        [320],
#        [315],
#        [326],
#        [339],
#        [311],
#        [334],
#        [332],
#        [321],
#        [324],
#        [326],
#        [312],
#        [315],
#        [309],
#        [306],
#        [297],
#        [315],
#        [298],
#        [318],
#        [317],
#        [329],
#        [322],
#        [302],
#        [313],
#        [293],
#        [311],
#        [312],
#        [334],
#        [322],
#        [323],
#        [321],
#        [320],
#        [329],
#        [319],
#        [309],
#        [307],
#        [300],
#        [305],
#        [299],
#        [314],
#        [316],
#        [327],
#        [317],
#        [335],
#        [331],
#        [324],
#        [324],
#        [323],
#        [322],
#        [336],
#        [316],
#        [307],
#        [306],
#        [310],
#        [311],
#        [313],
#        [317],
#        [315],
#        [340],
#        [334],
#        [298],
#        [295],
#        [315],
#        [310],
#        [305],
#        [301],
#        [325],
#        [328],
#        [338],
#        [333],
#        [331],
#        [330],
#        [322],
#        [321],
#        [324],
#        [312],
#        [313],
#        [316],
#        [324],
#        [308],
#        [305],
#        [296],
#        [306],
#        [312],
#        [318],
#        [324],
#        [313],
#        [319],
#        [312],
#        [304],
#        [330],
#        [326],
#        [325],
#        [329],
#        [310],
#        [299],
#        [296],
#        [317],
#        [324],
#        [325],
#        [314],
#        [328],
#        [316],
#        [311],
#        [324],
#        [321],
#        [320],
#        [316],
#        [318],
#        [335],
#        [321],
#        [307],
#        [309],
#        [324],
#        [326],
#        [331],
#        [327],
#        [312],
#        [308],
#        [324],
#        [325],
#        [313],
#        [312],
#        [314],
#        [327],
#        [308],
#        [306],
#        [299],
#        [294],
#        [312],
#        [315],
#        [322],
#        [329],
#        [320],
#        [308],
#        [304],
#        [311],
#        [317],
#        [312],
#        [321],
#        [340],
#        [331],
#        [336],
#        [324],
#        [314],
#        [313],
#        [307],
#        [300],
#        [302],
#        [312],
#        [316],
#        [317],
#        [310],
#        [320],
#        [330],
#        [305],
#        [309],
#        [319],
#        [322],
#        [323],
#        [313],
#        [321],
#        [323],
#        [325],
#        [312],
#        [308],
#        [320],
#        [328],
#        [311],
#        [301],
#        [305],
#        [308],
#        [298],
#        [300],
#        [324],
#        [327],
#        [317],
#        [323],
#        [314],
#        [305],
#        [315],
#        [326],
#        [299],
#        [295],
#        [324],
#        [297],
#        [327],
#        [311],
#        [308],
#        [319],
#        [312],
#        [325],
#        [319],
#        [332],
#        [323],
#        [324],
#        [312],
#        [326],
#        [308],
#        [305],
#        [295],
#        [316],
#        [304],
#        [299],
#        [302],
#        [313],
#        [318],
#        [325],
#        [303],
#        [300],
#        [297],
#        [317],
#        [327],
#        [301],
#        [314],
#        [321],
#        [322],
#        [334],
#        [338],
#        [306],
#        [313],
#        [330],
#        [320],
#        [311],
#        [298],
#        [301],
#        [310],
#        [324],
#        [336],
#        [321],
#        [315],
#        [304],
#        [297],
#        [290],
#        [303],
#        [311],
#        [322],
#        [319],
#        [324],
#        [300],
#        [340],
#        [335],
#        [302],
#        [307],
#        [296],
#        [320],
#        [314],
#        [318],
#        [326],
#        [317],
#        [329],
#        [324],
#        [325],
#        [330],
#        [312],
#        [333]], dtype=int64)

# %%
pt.scatter(x,y)
pt.xlabel('GRE SCORE')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
X_train.shape
# Out:
# (320, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predict=lm.predict(X_test)

# %%
Y_predict
# Out:
# array([[0.64740806],
#        [0.63728454],
#        [0.81950792],
#        [0.6170375 ],
#        [0.71827271],
#        [0.64740806],
#        [0.67777862],
#        [0.67777862],
#        [0.88024905],
#        [0.87012553],
#        [0.55629637],
#        [0.89037257],
#        [0.75876679],
#        [0.57654341],
#        [0.83975496],
#        [0.6676551 ],
#        [0.67777862],
#        [0.84987848],
#        [0.70814919],
#        [0.68790215],
#        [0.84987848],
#        [0.82963144],
#        [0.56641989],
#        [0.50567876],
#        [0.75876679],
#        [0.56641989],
#        [0.51580228],
#        [0.69802567],
#        [0.92074313],
#        [0.69802567],
#        [0.67777862],
#        [0.78913736],
#        [0.67777862],
#        [0.51580228],
#        [0.8093844 ],
#        [0.82963144],
#        [0.73851975],
#        [0.78913736],
#        [0.62716102],
#        [0.89037257],
#        [0.77901384],
#        [0.69802567],
#        [0.76889032],
#        [0.79926088],
#        [0.75876679],
#        [0.77901384],
#        [0.70814919],
#        [0.62716102],
#        [0.6170375 ],
#        [0.59679045],
#        [0.6676551 ],
#        [0.8093844 ],
#        [0.71827271],
#        [0.90049609],
#        [0.6676551 ],
#        [0.79926088],
#        [0.90049609],
#        [0.8093844 ],
#        [0.77901384],
#        [0.77901384],
#        [0.69802567],
#        [0.49555524],
#        [0.69802567],
#        [0.52592581],
#        [0.78913736],
#        [0.79926088],
#        [0.75876679],
#        [0.86000201],
#        [0.81950792],
#        [0.75876679],
#        [0.63728454],
#        [0.82963144],
#        [0.73851975],
#        [0.67777862],
#        [0.94099018],
#        [0.6676551 ],
#        [0.6170375 ],
#        [0.68790215],
#        [0.90049609],
#        [0.52592581]])

# %%
COMP=pd.DataFrame(X_test,columns=['GRE'])

# %%
COMP
# Out:
#     GRE
# 0   309
# 1   308
# 2   326
# 3   306
# 4   316
# ..  ...
# 75  311
# 76  306
# 77  313
# 78  334
# 79  297
#
# [80 rows x 1 columns]

# %%
COMP['AVLDATA']=Y_test

# %%
COMP
# Out:
#     GRE  AVLDATA
# 0   309     0.71
# 1   308     0.70
# 2   326     0.79
# 3   306     0.73
# 4   316     0.72
# ..  ...      ...
# 75  311     0.61
# 76  306     0.69
# 77  313     0.62
# 78  334     0.93
# 79  297     0.43
#
# [80 rows x 2 columns]

# %%
COMP['PRDDATA']=Y_predict

# %%
COMP
# Out:
#     GRE  AVLDATA   PRDDATA
# 0   309     0.71  0.647408
# 1   308     0.70  0.637285
# 2   326     0.79  0.819508
# 3   306     0.73  0.617037
# 4   316     0.72  0.718273
# ..  ...      ...       ...
# 75  311     0.61  0.667655
# 76  306     0.69  0.617037
# 77  313     0.62  0.687902
# 78  334     0.93  0.900496
# 79  297     0.43  0.525926
#
# [80 rows x 3 columns]

# %%
pt.scatter(x,y,color='blue')
pt.plot(X_test,Y_predict,color='red')
pt.xlabel('GRE SCORE')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(Y_test,Y_predict)
# Out:
# 0.008254091184558793

# %%
mean_absolute_error(Y_test,Y_predict)
# Out:
# 0.06577018755736426

# %%
r2_score(Y_test,Y_predict)
# Out:
# 0.5456668070172048

# %%
lm.score(X_test, Y_test)
# Out:
# 0.5456668070172048
