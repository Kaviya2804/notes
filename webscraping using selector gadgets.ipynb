# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://timesofindia.indiatimes.com/entertainment/top-rated-movies/tamil/best-movies/2023/2742916"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta charset="utf-8"/><title>Best Tamil Movies of 2023 | Top Rated Tamil Films of 2023 | Top 30 Best Tamil Movies  of 2023 | Etimes
# 		        </title><meta content="Best Tamil Movies of 2023 | Top Rated Tamil Films of 2023 | Top 30 Best Tamil Movies  of 2023 | Etimes
# 		        " property="og:title"/><meta content="Best Tamil Movies of 2023 | Top Rated Tamil Films of 2023 | Top 30 Best Tamil Movies  of 2023 | Etimes
# ...

# %%
name=soup.select("h3 a")

# %%
name
# Out:
# [<a href="/entertainment/tamil/movie-reviews/viduthalai-part-1/movie-review/99139534.cms">Viduthalai Part 1</a>,
#  <a href="/entertainment/tamil/movie-reviews/fight-club/movie-review/106031087.cms">Fight Club</a>,
#  <a href="/entertainment/tamil/movie-reviews/mark-antony/movie-review/103688195.cms">Mark Antony</a>,
#  <a href="/entertainment/tamil/movie-reviews/noodles/movie-review/103504503.cms">Noodles</a>,
#  <a href="/entertainment/tamil/movie-reviews/dd-returns/movie-review/102186072.cms">DD Returns</a>,
#  <a href="/entertainment/tamil/movie-reviews/aneethi/movie-review/102018606.cms">Aneethi</a>,
#  <a href="/entertainment/tamil/movie-reviews/por-thozhil/movie-review/100865937.cms">Por Thozhil</a>,
#  <a href="/entertainment/tamil/movie-reviews/good-night/movie-review/100151118.cms">Good Night</a>,
#  <a href="/entertainment/tamil/movie-reviews/ponniyin-selvan-part-2/movie-review/99838449.cms">Ponniyin Selvan: Part 2</a>,
# ...

# %%
rating=soup.select(".md_info , h4")

# %%
rating
# Out:
# [<h4><a catkey="27135527" class="active" data-action="Navigation_DropdownItem" data-ga="true" data-label="News" geolangpattern="https://timesofindia.indiatimes.com/entertainment/" geolangpattern1="/movies/news" href="https://timesofindia.indiatimes.com/entertainment/movies/news" key="27135527">News</a></h4>,
#  <h4><a catkey="135762" class="active" data-action="Navigation_DropdownItem" data-ga="true" data-label="Movie Reviews" geolangpattern="https://timesofindia.indiatimes.com/entertainment/" geolangpattern1="/movie-reviews" href="https://timesofindia.indiatimes.com/entertainment/movie-reviews" key="135762">Movie Reviews</a></h4>,
# ...

# %%
date=soup.select("h4")

# %%
date
# Out:
# [<h4><a catkey="27135527" class="active" data-action="Navigation_DropdownItem" data-ga="true" data-label="News" geolangpattern="https://timesofindia.indiatimes.com/entertainment/" geolangpattern1="/movies/news" href="https://timesofindia.indiatimes.com/entertainment/movies/news" key="27135527">News</a></h4>,
#  <h4><a catkey="135762" class="active" data-action="Navigation_DropdownItem" data-ga="true" data-label="Movie Reviews" geolangpattern="https://timesofindia.indiatimes.com/entertainment/" geolangpattern1="/movie-reviews" href="https://timesofindia.indiatimes.com/entertainment/movie-reviews" key="135762">Movie Reviews</a></h4>,
# ...

# %%
import pandas

# %%
Movielist=pandas.DataFrame(name,columns=['Name'])

# %%
Movielist
# Out:
#                                    Name
# 0                     Viduthalai Part 1
# 1                            Fight Club
# 2                           Mark Antony
# 3                               Noodles
# 4                            DD Returns
# 5                               Aneethi
# 6                           Por Thozhil
# 7                            Good Night
# 8               Ponniyin Selvan: Part 2
# 9                            Kudimahaan
# 10                               Ayothi
# 11                                 Dada
# 12             The Great Indian Kitchen
# 13             The Great Indian Kitchen
# 14                               Varisu
# 15                  Aayiram Porkaasukal
# 16                              Kannagi
# 17  Odavum Mudiyadhu Oliyavum Mudiyadhu
# 18                  Conjuring Kannappan
# 19     Annapoorani: The Goddess Of Food
# 20                  Jigarthanda DoubleX
# 21                     Margazhi Thingal
# ...

# %%
Movielist["date"]=date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Movielist["date"]=date
#
# File ~\anaconda3\envs\kaviya17\lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\envs\kaviya17\lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
# ...
