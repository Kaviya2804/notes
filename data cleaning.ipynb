# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\aedpu\anaconda3\envs\kaviya17\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
var=pd.read_csv("C:\\Users\\aedpu\\Downloads\\Realmephones.csv")

# %%
var
# Out:
#     Unnamed: 0                                 Mobile title  \
# 0            0             realme C51 (Carbon Black, 64 GB)
# 1            1              realme C51 (Mint Green, 128 GB)
# 2            2               realme C51 (Mint Green, 64 GB)
# 3            3            realme C51 (Carbon Black, 128 GB)
# 4            4      realme 12x 5G (Twilight Purple, 128 GB)
# 5            5         realme P1 5G (Peacock Green, 256 GB)
# 6            6         realme P1 5G (Peacock Green, 128 GB)
# 7            7           realme P1 5G (Phoenix Red, 128 GB)
# 8            8      realme 12x 5G (Twilight Purple, 128 GB)
# 9            9       realme 12x 5G (Woodland Green, 128 GB)
# 10          10           realme P1 5G (Phoenix Red, 256 GB)
# 11          11       realme 12x 5G (Woodland Green, 128 GB)
# 12          12           realme P1 5G (Phoenix Red, 128 GB)
# 13          13         realme P1 5G (Peacock Green, 128 GB)
# 14          14           realme C53 (Champion Black, 64 GB)
# 15          15          realme C53 (Champion Black, 128 GB)
# 16          16            realme C53 (Champion Gold, 64 GB)
# 17          17           realme C53 (Champion Gold, 128 GB)
# 18          18          realme C53 (Champion Black, 128 GB)
# 19          19           realme C53 (Champion Gold, 128 GB)
# 20          20  realme 12 Pro+ 5G (Navigator Beige, 256 GB)
# 21          21        realme C65 5G (Glowing Black, 128 GB)
# 22          22        realme C65 5G (Feather Green, 128 GB)
# 23          23        realme C65 5G (Glowing Black, 128 GB)
#
#                                                Memory  \
# 0   <li class="J+igdf">4 GB RAM | 64 GB ROM | Expa...
# 1   <li class="J+igdf">4 GB RAM | 128 GB ROM | Exp...
# 2   <li class="J+igdf">4 GB RAM | 64 GB ROM | Expa...
# 3   <li class="J+igdf">4 GB RAM | 128 GB ROM | Exp...
# 4   <li class="J+igdf">8 GB RAM | 128 GB ROM | Exp...
# 5   <li class="J+igdf">8 GB RAM | 256 GB ROM | Exp...
# 6   <li class="J+igdf">6 GB RAM | 128 GB ROM | Exp...
# 7   <li class="J+igdf">6 GB RAM | 128 GB ROM | Exp...
# 8   <li class="J+igdf">6 GB RAM | 128 GB ROM | Exp...
# 9   <li class="J+igdf">6 GB RAM | 128 GB ROM | Exp...
# 10  <li class="J+igdf">8 GB RAM | 256 GB ROM | Exp...
# 11  <li class="J+igdf">8 GB RAM | 128 GB ROM | Exp...
# 12  <li class="J+igdf">8 GB RAM | 128 GB ROM | Exp...
# 13  <li class="J+igdf">8 GB RAM | 128 GB ROM | Exp...
# 14  <li class="J+igdf">6 GB RAM | 64 GB ROM | Expa...
# 15  <li class="J+igdf">6 GB RAM | 128 GB ROM | Exp...
# 16  <li class="J+igdf">6 GB RAM | 64 GB ROM | Expa...
# 17  <li class="J+igdf">6 GB RAM | 128 GB ROM | Exp...
# 18  <li class="J+igdf">4 GB RAM | 128 GB ROM | Exp...
# 19  <li class="J+igdf">4 GB RAM | 128 GB ROM | Exp...
# 20     <li class="J+igdf">12 GB RAM | 256 GB ROM</li>
# 21  <li class="J+igdf">4 GB RAM | 128 GB ROM | Exp...
# 22  <li class="J+igdf">6 GB RAM | 128 GB ROM | Exp...
# 23  <li class="J+igdf">6 GB RAM | 128 GB ROM | Exp...
#
#                                         Price  \
# 0    <div class="Nx9bqj _4b5DiR">₹7,999</div>
# 1    <div class="Nx9bqj _4b5DiR">₹9,499</div>
# 2    <div class="Nx9bqj _4b5DiR">₹7,999</div>
# 3    <div class="Nx9bqj _4b5DiR">₹9,499</div>
# 4   <div class="Nx9bqj _4b5DiR">₹14,999</div>
# 5   <div class="Nx9bqj _4b5DiR">₹18,999</div>
# 6   <div class="Nx9bqj _4b5DiR">₹15,999</div>
# 7   <div class="Nx9bqj _4b5DiR">₹15,999</div>
# 8   <div class="Nx9bqj _4b5DiR">₹12,999</div>
# 9   <div class="Nx9bqj _4b5DiR">₹12,999</div>
# 10  <div class="Nx9bqj _4b5DiR">₹18,999</div>
# 11  <div class="Nx9bqj _4b5DiR">₹14,999</div>
# 12  <div class="Nx9bqj _4b5DiR">₹16,999</div>
# 13  <div class="Nx9bqj _4b5DiR">₹16,999</div>
# 14  <div class="Nx9bqj _4b5DiR">₹10,999</div>
# 15   <div class="Nx9bqj _4b5DiR">₹9,999</div>
# 16  <div class="Nx9bqj _4b5DiR">₹10,999</div>
# 17   <div class="Nx9bqj _4b5DiR">₹9,999</div>
# 18   <div class="Nx9bqj _4b5DiR">₹8,999</div>
# 19   <div class="Nx9bqj _4b5DiR">₹8,999</div>
# 20  <div class="Nx9bqj _4b5DiR">₹31,999</div>
# 21  <div class="Nx9bqj _4b5DiR">₹11,499</div>
# 22  <div class="Nx9bqj _4b5DiR">₹12,499</div>
# 23  <div class="Nx9bqj _4b5DiR">₹12,499</div>
#
#                                             Processor
# 0              <li class="J+igdf">T612 Processor</li>
# 1              <li class="J+igdf">T612 Processor</li>
# 2              <li class="J+igdf">T612 Processor</li>
# 3              <li class="J+igdf">T612 Processor</li>
# 4   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 5    <li class="J+igdf">Dimensity 7050 Processor</li>
# 6    <li class="J+igdf">Dimensity 7050 Processor</li>
# 7    <li class="J+igdf">Dimensity 7050 Processor</li>
# 8   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 9   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 10   <li class="J+igdf">Dimensity 7050 Processor</li>
# 11  <li class="J+igdf">Dimensity 6100+ Processor</li>
# 12   <li class="J+igdf">Dimensity 7050 Processor</li>
# 13   <li class="J+igdf">Dimensity 7050 Processor</li>
# 14             <li class="J+igdf">T612 Processor</li>
# 15             <li class="J+igdf">T612 Processor</li>
# 16             <li class="J+igdf">T612 Processor</li>
# 17             <li class="J+igdf">T612 Processor</li>
# 18             <li class="J+igdf">T612 Processor</li>
# 19             <li class="J+igdf">T612 Processor</li>
# 20  <li class="J+igdf">Snapdragon 7s Gen 2 Process...
# 21   <li class="J+igdf">Dimensity 6300 Processor</li>
# 22   <li class="J+igdf">Dimensity 6300 Processor</li>
# 23   <li class="J+igdf">Dimensity 6300 Processor</li>

# %%
var.drop('Unnamed: 0', inplace=True,axis=1)

# %%
var["Memory"]=var["Memory"].str.strip('<li class="J+igdf">').astype(str)

# %%
var["Memory"]=var["Memory"].str.strip('Expa..').astype(str)

# %%
var
# Out:
#                                    Mobile title  \
# 0              realme C51 (Carbon Black, 64 GB)
# 1               realme C51 (Mint Green, 128 GB)
# 2                realme C51 (Mint Green, 64 GB)
# 3             realme C51 (Carbon Black, 128 GB)
# 4       realme 12x 5G (Twilight Purple, 128 GB)
# 5          realme P1 5G (Peacock Green, 256 GB)
# 6          realme P1 5G (Peacock Green, 128 GB)
# 7            realme P1 5G (Phoenix Red, 128 GB)
# 8       realme 12x 5G (Twilight Purple, 128 GB)
# 9        realme 12x 5G (Woodland Green, 128 GB)
# 10           realme P1 5G (Phoenix Red, 256 GB)
# 11       realme 12x 5G (Woodland Green, 128 GB)
# 12           realme P1 5G (Phoenix Red, 128 GB)
# 13         realme P1 5G (Peacock Green, 128 GB)
# 14           realme C53 (Champion Black, 64 GB)
# 15          realme C53 (Champion Black, 128 GB)
# 16            realme C53 (Champion Gold, 64 GB)
# 17           realme C53 (Champion Gold, 128 GB)
# 18          realme C53 (Champion Black, 128 GB)
# 19           realme C53 (Champion Gold, 128 GB)
# 20  realme 12 Pro+ 5G (Navigator Beige, 256 GB)
# 21        realme C65 5G (Glowing Black, 128 GB)
# 22        realme C65 5G (Feather Green, 128 GB)
# 23        realme C65 5G (Glowing Black, 128 GB)
#
#                                             Memory  \
# 0    4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</
# 1   4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 2    4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</
# 3   4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 4   8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 5   8 GB RAM | 256 GB ROM | Expandable Upto 2 TB</
# 6   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 7   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 8   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 9   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 10  8 GB RAM | 256 GB ROM | Expandable Upto 2 TB</
# 11  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 12  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 13  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 14   6 GB RAM | 64 GB ROM | Expandable Upto 2 TB</
# 15  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 16   6 GB RAM | 64 GB ROM | Expandable Upto 2 TB</
# 17  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 18  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 19  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 20                        12 GB RAM | 256 GB ROM</
# 21  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 22  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 23  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
#
#                                         Price  \
# 0    <div class="Nx9bqj _4b5DiR">₹7,999</div>
# 1    <div class="Nx9bqj _4b5DiR">₹9,499</div>
# 2    <div class="Nx9bqj _4b5DiR">₹7,999</div>
# 3    <div class="Nx9bqj _4b5DiR">₹9,499</div>
# 4   <div class="Nx9bqj _4b5DiR">₹14,999</div>
# 5   <div class="Nx9bqj _4b5DiR">₹18,999</div>
# 6   <div class="Nx9bqj _4b5DiR">₹15,999</div>
# 7   <div class="Nx9bqj _4b5DiR">₹15,999</div>
# 8   <div class="Nx9bqj _4b5DiR">₹12,999</div>
# 9   <div class="Nx9bqj _4b5DiR">₹12,999</div>
# 10  <div class="Nx9bqj _4b5DiR">₹18,999</div>
# 11  <div class="Nx9bqj _4b5DiR">₹14,999</div>
# 12  <div class="Nx9bqj _4b5DiR">₹16,999</div>
# 13  <div class="Nx9bqj _4b5DiR">₹16,999</div>
# 14  <div class="Nx9bqj _4b5DiR">₹10,999</div>
# 15   <div class="Nx9bqj _4b5DiR">₹9,999</div>
# 16  <div class="Nx9bqj _4b5DiR">₹10,999</div>
# 17   <div class="Nx9bqj _4b5DiR">₹9,999</div>
# 18   <div class="Nx9bqj _4b5DiR">₹8,999</div>
# 19   <div class="Nx9bqj _4b5DiR">₹8,999</div>
# 20  <div class="Nx9bqj _4b5DiR">₹31,999</div>
# 21  <div class="Nx9bqj _4b5DiR">₹11,499</div>
# 22  <div class="Nx9bqj _4b5DiR">₹12,499</div>
# 23  <div class="Nx9bqj _4b5DiR">₹12,499</div>
#
#                                             Processor
# 0              <li class="J+igdf">T612 Processor</li>
# 1              <li class="J+igdf">T612 Processor</li>
# 2              <li class="J+igdf">T612 Processor</li>
# 3              <li class="J+igdf">T612 Processor</li>
# 4   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 5    <li class="J+igdf">Dimensity 7050 Processor</li>
# 6    <li class="J+igdf">Dimensity 7050 Processor</li>
# 7    <li class="J+igdf">Dimensity 7050 Processor</li>
# 8   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 9   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 10   <li class="J+igdf">Dimensity 7050 Processor</li>
# 11  <li class="J+igdf">Dimensity 6100+ Processor</li>
# 12   <li class="J+igdf">Dimensity 7050 Processor</li>
# 13   <li class="J+igdf">Dimensity 7050 Processor</li>
# 14             <li class="J+igdf">T612 Processor</li>
# 15             <li class="J+igdf">T612 Processor</li>
# 16             <li class="J+igdf">T612 Processor</li>
# 17             <li class="J+igdf">T612 Processor</li>
# 18             <li class="J+igdf">T612 Processor</li>
# 19             <li class="J+igdf">T612 Processor</li>
# 20  <li class="J+igdf">Snapdragon 7s Gen 2 Process...
# 21   <li class="J+igdf">Dimensity 6300 Processor</li>
# 22   <li class="J+igdf">Dimensity 6300 Processor</li>
# 23   <li class="J+igdf">Dimensity 6300 Processor</li>

# %%
var["Memory"]=var["Memory"].str.strip('Expandable Upto 2 TB')

# %%
var
# Out:
#                                    Mobile title  \
# 0              realme C51 (Carbon Black, 64 GB)
# 1               realme C51 (Mint Green, 128 GB)
# 2                realme C51 (Mint Green, 64 GB)
# 3             realme C51 (Carbon Black, 128 GB)
# 4       realme 12x 5G (Twilight Purple, 128 GB)
# 5          realme P1 5G (Peacock Green, 256 GB)
# 6          realme P1 5G (Peacock Green, 128 GB)
# 7            realme P1 5G (Phoenix Red, 128 GB)
# 8       realme 12x 5G (Twilight Purple, 128 GB)
# 9        realme 12x 5G (Woodland Green, 128 GB)
# 10           realme P1 5G (Phoenix Red, 256 GB)
# 11       realme 12x 5G (Woodland Green, 128 GB)
# 12           realme P1 5G (Phoenix Red, 128 GB)
# 13         realme P1 5G (Peacock Green, 128 GB)
# 14           realme C53 (Champion Black, 64 GB)
# 15          realme C53 (Champion Black, 128 GB)
# 16            realme C53 (Champion Gold, 64 GB)
# 17           realme C53 (Champion Gold, 128 GB)
# 18          realme C53 (Champion Black, 128 GB)
# 19           realme C53 (Champion Gold, 128 GB)
# 20  realme 12 Pro+ 5G (Navigator Beige, 256 GB)
# 21        realme C65 5G (Glowing Black, 128 GB)
# 22        realme C65 5G (Feather Green, 128 GB)
# 23        realme C65 5G (Glowing Black, 128 GB)
#
#                                             Memory  \
# 0    4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</
# 1   4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 2    4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</
# 3   4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 4   8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 5   8 GB RAM | 256 GB ROM | Expandable Upto 2 TB</
# 6   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 7   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 8   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 9   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 10  8 GB RAM | 256 GB ROM | Expandable Upto 2 TB</
# 11  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 12  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 13  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 14   6 GB RAM | 64 GB ROM | Expandable Upto 2 TB</
# 15  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 16   6 GB RAM | 64 GB ROM | Expandable Upto 2 TB</
# 17  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 18  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 19  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 20                        12 GB RAM | 256 GB ROM</
# 21  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 22  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
# 23  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</
#
#                                         Price  \
# 0    <div class="Nx9bqj _4b5DiR">₹7,999</div>
# 1    <div class="Nx9bqj _4b5DiR">₹9,499</div>
# 2    <div class="Nx9bqj _4b5DiR">₹7,999</div>
# 3    <div class="Nx9bqj _4b5DiR">₹9,499</div>
# 4   <div class="Nx9bqj _4b5DiR">₹14,999</div>
# 5   <div class="Nx9bqj _4b5DiR">₹18,999</div>
# 6   <div class="Nx9bqj _4b5DiR">₹15,999</div>
# 7   <div class="Nx9bqj _4b5DiR">₹15,999</div>
# 8   <div class="Nx9bqj _4b5DiR">₹12,999</div>
# 9   <div class="Nx9bqj _4b5DiR">₹12,999</div>
# 10  <div class="Nx9bqj _4b5DiR">₹18,999</div>
# 11  <div class="Nx9bqj _4b5DiR">₹14,999</div>
# 12  <div class="Nx9bqj _4b5DiR">₹16,999</div>
# 13  <div class="Nx9bqj _4b5DiR">₹16,999</div>
# 14  <div class="Nx9bqj _4b5DiR">₹10,999</div>
# 15   <div class="Nx9bqj _4b5DiR">₹9,999</div>
# 16  <div class="Nx9bqj _4b5DiR">₹10,999</div>
# 17   <div class="Nx9bqj _4b5DiR">₹9,999</div>
# 18   <div class="Nx9bqj _4b5DiR">₹8,999</div>
# 19   <div class="Nx9bqj _4b5DiR">₹8,999</div>
# 20  <div class="Nx9bqj _4b5DiR">₹31,999</div>
# 21  <div class="Nx9bqj _4b5DiR">₹11,499</div>
# 22  <div class="Nx9bqj _4b5DiR">₹12,499</div>
# 23  <div class="Nx9bqj _4b5DiR">₹12,499</div>
#
#                                             Processor
# 0              <li class="J+igdf">T612 Processor</li>
# 1              <li class="J+igdf">T612 Processor</li>
# 2              <li class="J+igdf">T612 Processor</li>
# 3              <li class="J+igdf">T612 Processor</li>
# 4   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 5    <li class="J+igdf">Dimensity 7050 Processor</li>
# 6    <li class="J+igdf">Dimensity 7050 Processor</li>
# 7    <li class="J+igdf">Dimensity 7050 Processor</li>
# 8   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 9   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 10   <li class="J+igdf">Dimensity 7050 Processor</li>
# 11  <li class="J+igdf">Dimensity 6100+ Processor</li>
# 12   <li class="J+igdf">Dimensity 7050 Processor</li>
# 13   <li class="J+igdf">Dimensity 7050 Processor</li>
# 14             <li class="J+igdf">T612 Processor</li>
# 15             <li class="J+igdf">T612 Processor</li>
# 16             <li class="J+igdf">T612 Processor</li>
# 17             <li class="J+igdf">T612 Processor</li>
# 18             <li class="J+igdf">T612 Processor</li>
# 19             <li class="J+igdf">T612 Processor</li>
# 20  <li class="J+igdf">Snapdragon 7s Gen 2 Process...
# 21   <li class="J+igdf">Dimensity 6300 Processor</li>
# 22   <li class="J+igdf">Dimensity 6300 Processor</li>
# 23   <li class="J+igdf">Dimensity 6300 Processor</li>

# %%
var["Price"]=var["Price"].str.strip('<div class="Nx9bqj _4b5DiR">')

# %%
var["Price"]=var["Price"].str.strip('</div>')

# %%
var
# Out:
#                                    Mobile title  \
# 0              realme C51 (Carbon Black, 64 GB)
# 1               realme C51 (Mint Green, 128 GB)
# 2                realme C51 (Mint Green, 64 GB)
# 3             realme C51 (Carbon Black, 128 GB)
# 4       realme 12x 5G (Twilight Purple, 128 GB)
# 5          realme P1 5G (Peacock Green, 256 GB)
# 6          realme P1 5G (Peacock Green, 128 GB)
# 7            realme P1 5G (Phoenix Red, 128 GB)
# 8       realme 12x 5G (Twilight Purple, 128 GB)
# 9        realme 12x 5G (Woodland Green, 128 GB)
# 10           realme P1 5G (Phoenix Red, 256 GB)
# 11       realme 12x 5G (Woodland Green, 128 GB)
# 12           realme P1 5G (Phoenix Red, 128 GB)
# 13         realme P1 5G (Peacock Green, 128 GB)
# 14           realme C53 (Champion Black, 64 GB)
# 15          realme C53 (Champion Black, 128 GB)
# 16            realme C53 (Champion Gold, 64 GB)
# 17           realme C53 (Champion Gold, 128 GB)
# 18          realme C53 (Champion Black, 128 GB)
# 19           realme C53 (Champion Gold, 128 GB)
# 20  realme 12 Pro+ 5G (Navigator Beige, 256 GB)
# 21        realme C65 5G (Glowing Black, 128 GB)
# 22        realme C65 5G (Feather Green, 128 GB)
# 23        realme C65 5G (Glowing Black, 128 GB)
#
#                                             Memory Price  \
# 0    4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</   ₹7,
# 1   4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹9,
# 2    4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</   ₹7,
# 3   4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹9,
# 4   8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹14,
# 5   8 GB RAM | 256 GB ROM | Expandable Upto 2 TB</  ₹18,
# 6   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹15,
# 7   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹15,
# 8   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹12,
# 9   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹12,
# 10  8 GB RAM | 256 GB ROM | Expandable Upto 2 TB</  ₹18,
# 11  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹14,
# 12  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹16,
# 13  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹16,
# 14   6 GB RAM | 64 GB ROM | Expandable Upto 2 TB</  ₹10,
# 15  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹9,
# 16   6 GB RAM | 64 GB ROM | Expandable Upto 2 TB</  ₹10,
# 17  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹9,
# 18  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹8,
# 19  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹8,
# 20                        12 GB RAM | 256 GB ROM</  ₹31,
# 21  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹11,
# 22  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹12,
# 23  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹12,
#
#                                             Processor
# 0              <li class="J+igdf">T612 Processor</li>
# 1              <li class="J+igdf">T612 Processor</li>
# 2              <li class="J+igdf">T612 Processor</li>
# 3              <li class="J+igdf">T612 Processor</li>
# 4   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 5    <li class="J+igdf">Dimensity 7050 Processor</li>
# 6    <li class="J+igdf">Dimensity 7050 Processor</li>
# 7    <li class="J+igdf">Dimensity 7050 Processor</li>
# 8   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 9   <li class="J+igdf">Dimensity 6100+ Processor</li>
# 10   <li class="J+igdf">Dimensity 7050 Processor</li>
# 11  <li class="J+igdf">Dimensity 6100+ Processor</li>
# 12   <li class="J+igdf">Dimensity 7050 Processor</li>
# 13   <li class="J+igdf">Dimensity 7050 Processor</li>
# 14             <li class="J+igdf">T612 Processor</li>
# 15             <li class="J+igdf">T612 Processor</li>
# 16             <li class="J+igdf">T612 Processor</li>
# 17             <li class="J+igdf">T612 Processor</li>
# 18             <li class="J+igdf">T612 Processor</li>
# 19             <li class="J+igdf">T612 Processor</li>
# 20  <li class="J+igdf">Snapdragon 7s Gen 2 Process...
# 21   <li class="J+igdf">Dimensity 6300 Processor</li>
# 22   <li class="J+igdf">Dimensity 6300 Processor</li>
# 23   <li class="J+igdf">Dimensity 6300 Processor</li>

# %%
var["Processor"]=var["Processor"].str.strip('<li class="J+igdf">')

# %%
var["Processor"]=var["Processor"].str.strip('</li>')

# %%
var
# Out:
#                                    Mobile title  \
# 0              realme C51 (Carbon Black, 64 GB)
# 1               realme C51 (Mint Green, 128 GB)
# 2                realme C51 (Mint Green, 64 GB)
# 3             realme C51 (Carbon Black, 128 GB)
# 4       realme 12x 5G (Twilight Purple, 128 GB)
# 5          realme P1 5G (Peacock Green, 256 GB)
# 6          realme P1 5G (Peacock Green, 128 GB)
# 7            realme P1 5G (Phoenix Red, 128 GB)
# 8       realme 12x 5G (Twilight Purple, 128 GB)
# 9        realme 12x 5G (Woodland Green, 128 GB)
# 10           realme P1 5G (Phoenix Red, 256 GB)
# 11       realme 12x 5G (Woodland Green, 128 GB)
# 12           realme P1 5G (Phoenix Red, 128 GB)
# 13         realme P1 5G (Peacock Green, 128 GB)
# 14           realme C53 (Champion Black, 64 GB)
# 15          realme C53 (Champion Black, 128 GB)
# 16            realme C53 (Champion Gold, 64 GB)
# 17           realme C53 (Champion Gold, 128 GB)
# 18          realme C53 (Champion Black, 128 GB)
# 19           realme C53 (Champion Gold, 128 GB)
# 20  realme 12 Pro+ 5G (Navigator Beige, 256 GB)
# 21        realme C65 5G (Glowing Black, 128 GB)
# 22        realme C65 5G (Feather Green, 128 GB)
# 23        realme C65 5G (Glowing Black, 128 GB)
#
#                                             Memory Price  \
# 0    4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</   ₹7,
# 1   4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹9,
# 2    4 GB RAM | 64 GB ROM | Expandable Upto 2 TB</   ₹7,
# 3   4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹9,
# 4   8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹14,
# 5   8 GB RAM | 256 GB ROM | Expandable Upto 2 TB</  ₹18,
# 6   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹15,
# 7   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹15,
# 8   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹12,
# 9   6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹12,
# 10  8 GB RAM | 256 GB ROM | Expandable Upto 2 TB</  ₹18,
# 11  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹14,
# 12  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹16,
# 13  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹16,
# 14   6 GB RAM | 64 GB ROM | Expandable Upto 2 TB</  ₹10,
# 15  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹9,
# 16   6 GB RAM | 64 GB ROM | Expandable Upto 2 TB</  ₹10,
# 17  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹9,
# 18  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹8,
# 19  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</   ₹8,
# 20                        12 GB RAM | 256 GB ROM</  ₹31,
# 21  4 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹11,
# 22  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹12,
# 23  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB</  ₹12,
#
#                         Processor
# 0                  T612 Processor
# 1                  T612 Processor
# 2                  T612 Processor
# 3                  T612 Processor
# 4       Dimensity 6100+ Processor
# 5        Dimensity 7050 Processor
# 6        Dimensity 7050 Processor
# 7        Dimensity 7050 Processor
# 8       Dimensity 6100+ Processor
# 9       Dimensity 6100+ Processor
# 10       Dimensity 7050 Processor
# 11      Dimensity 6100+ Processor
# 12       Dimensity 7050 Processor
# 13       Dimensity 7050 Processor
# 14                 T612 Processor
# 15                 T612 Processor
# 16                 T612 Processor
# 17                 T612 Processor
# 18                 T612 Processor
# 19                 T612 Processor
# 20  Snapdragon 7s Gen 2 Processor
# 21       Dimensity 6300 Processor
# 22       Dimensity 6300 Processor
# 23       Dimensity 6300 Processor

# %%
var.to_csv("C:\\Users\\aedpu\\OneDrive\\Documents.csv")
